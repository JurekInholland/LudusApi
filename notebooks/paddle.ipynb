# %% [markdown]
# # Paddle detection

# %%
import cv2
from ultralytics import YOLO

model = YOLO('../models/paddletracker_v2.2.pt')
video_path = '../uploads/5m7eaEFF8HPqpRZw8jykEtPADDLE_2_1.mp4'
cap = cv2.VideoCapture(video_path)

current_frame_number = 0
paddle_states = []

threshold = 0.49

def paddle_analysis(frame):
    result = model.predict(frame, threshold)
    result = list(result)  # Convert to a list
    boxes = result[0].boxes.xyxy.cuda()
    scores = result[0].boxes.conf.cuda()
    class_ids = result[0].names

    image = frame.copy()  # Create a copy of the frame
    cv2.putText(image, str(current_frame_number), (0, 900), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    for box, score, class_id in zip(boxes, scores, class_ids):
        if class_id == 1:
            if score > threshold:
                cv2.putText(image, "Paddle score: " + str(score), (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        if class_id == 0:
            cv2.putText(image, "Score: " + str(score), (500, 150), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 0), 2)

    if current_frame_number > 500: 
        cv2.imshow("Frame", image)
        cv2.waitKey(0)
        cv2.destroyAllWindows()


while cap.isOpened():
    ret, frame = cap.read()

    if not ret or frame is None or frame.shape[0] == 0 or frame.shape[1] == 0:
        break

    # Process every 5 frames
    if current_frame_number % 5 == 0:
        paddle_result = paddle_analysis(frame)
        if paddle_result is not None:
            paddle_states.append(paddle_result)

    current_frame_number += 1
# Out:
# WARNING  Ultralytics settings reset to defaults. This is normal and may be due to a recent ultralytics package update, but may have overwritten previous settings.
# View and update settings with 'yolo settings' or at 'C:\Users\jurek\AppData\Roaming\Ultralytics\settings.yaml'
#
# 0: 480x800 1 paddle, 89.0ms
# Speed: 8.0ms preprocess, 89.0ms inference, 13.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 48.7ms
# Speed: 1.0ms preprocess, 48.7ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 42.0ms
# Speed: 1.0ms preprocess, 42.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 4.4ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.6ms
# Speed: 0.5ms preprocess, 11.6ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 12.9ms
# Speed: 1.0ms preprocess, 12.9ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 2.2ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.4ms
# Speed: 1.0ms preprocess, 11.4ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.6ms
# Speed: 0.0ms preprocess, 11.6ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 10.6ms
# Speed: 0.0ms preprocess, 10.6ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.3ms
# Speed: 0.6ms preprocess, 11.3ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 2 light_greens, 1 paddle, 11.9ms
# Speed: 1.0ms preprocess, 11.9ms inference, 3.7ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 12.2ms
# Speed: 1.1ms preprocess, 12.2ms inference, 2.8ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 11.5ms
# Speed: 1.1ms preprocess, 11.5ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.3ms
# Speed: 1.0ms preprocess, 11.3ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 17.6ms
# Speed: 1.0ms preprocess, 17.6ms inference, 4.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 10.4ms
# Speed: 0.6ms preprocess, 10.4ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 3.4ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 9.8ms
# Speed: 0.5ms preprocess, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 13.0ms
# Speed: 0.0ms preprocess, 13.0ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 12.6ms
# Speed: 0.7ms preprocess, 12.6ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 2 light_greens, 1 paddle, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 2 light_greens, 1 paddle, 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 13.0ms
# Speed: 0.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 13.8ms
# Speed: 1.0ms preprocess, 13.8ms inference, 3.3ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 11.6ms
# Speed: 1.0ms preprocess, 11.6ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 174.0ms
# Speed: 3.1ms preprocess, 174.0ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 4.3ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 2 light_greens, 1 paddle, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 24.0ms
# Speed: 0.0ms preprocess, 24.0ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 25.3ms
# Speed: 0.0ms preprocess, 25.3ms inference, 3.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 33.1ms
# Speed: 1.0ms preprocess, 33.1ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 27.1ms
# Speed: 1.0ms preprocess, 27.1ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 2 light_greens, 1 paddle, 43.5ms
# Speed: 0.0ms preprocess, 43.5ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 2 light_greens, 1 paddle, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 30.7ms
# Speed: 1.0ms preprocess, 30.7ms inference, 5.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 28.7ms
# Speed: 1.0ms preprocess, 28.7ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 26.0ms
# Speed: 1.0ms preprocess, 26.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 39.2ms
# Speed: 0.0ms preprocess, 39.2ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 29.8ms
# Speed: 1.0ms preprocess, 29.8ms inference, 3.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 29.4ms
# Speed: 0.0ms preprocess, 29.4ms inference, 5.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 4.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 30.7ms
# Speed: 0.0ms preprocess, 30.7ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 35.9ms
# Speed: 1.0ms preprocess, 35.9ms inference, 5.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 28.4ms
# Speed: 0.0ms preprocess, 28.4ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 50.9ms
# Speed: 1.0ms preprocess, 50.9ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 35.8ms
# Speed: 1.0ms preprocess, 35.8ms inference, 6.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 26.1ms
# Speed: 0.0ms preprocess, 26.1ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 26.8ms
# Speed: 1.0ms preprocess, 26.8ms inference, 7.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 26.0ms
# Speed: 1.0ms preprocess, 26.0ms inference, 4.1ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 34.8ms
# Speed: 1.0ms preprocess, 34.8ms inference, 5.6ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 35.5ms
# Speed: 0.0ms preprocess, 35.5ms inference, 5.3ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 28.6ms
# Speed: 0.0ms preprocess, 28.6ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 38.1ms
# Speed: 0.0ms preprocess, 38.1ms inference, 5.7ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 27.8ms
# Speed: 1.0ms preprocess, 27.8ms inference, 4.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 32.0ms
# Speed: 1.0ms preprocess, 32.0ms inference, 5.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 42.2ms
# Speed: 1.0ms preprocess, 42.2ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 39.8ms
# Speed: 1.0ms preprocess, 39.8ms inference, 4.8ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 31.6ms
# Speed: 0.5ms preprocess, 31.6ms inference, 4.6ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 32.6ms
# Speed: 1.0ms preprocess, 32.6ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 29.4ms
# Speed: 0.0ms preprocess, 29.4ms inference, 6.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 37.2ms
# Speed: 1.0ms preprocess, 37.2ms inference, 4.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 30.0ms
# Speed: 0.0ms preprocess, 30.0ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 31.1ms
# Speed: 1.0ms preprocess, 31.1ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 5.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 37.1ms
# Speed: 1.0ms preprocess, 37.1ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 (no detections), 45.9ms
# Speed: 1.0ms preprocess, 45.9ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 35.8ms
# Speed: 2.0ms preprocess, 35.8ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 41.1ms
# Speed: 1.0ms preprocess, 41.1ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 29.5ms
# Speed: 0.0ms preprocess, 29.5ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 38.2ms
# Speed: 1.0ms preprocess, 38.2ms inference, 5.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 33.8ms
# Speed: 1.0ms preprocess, 33.8ms inference, 5.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 39.0ms
# Speed: 0.0ms preprocess, 39.0ms inference, 4.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 light_green, 1 paddle, 44.7ms
# Speed: 1.0ms preprocess, 44.7ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 36.2ms
# Speed: 0.0ms preprocess, 36.2ms inference, 5.6ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 43.1ms
# Speed: 1.0ms preprocess, 43.1ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 26.2ms
# Speed: 1.0ms preprocess, 26.2ms inference, 4.4ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 27.7ms
# Speed: 1.0ms preprocess, 27.7ms inference, 3.2ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 paddle, 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 800)
